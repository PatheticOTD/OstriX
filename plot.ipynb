# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_normal_a = pd.read_csv('D:\\normal_points_a.csv')
df_normal_b = pd.read_csv('D:\\normal_points_b.csv')
df_uniform = pd.read_csv('D:\\uniform_points.csv')

# %%
plt.scatter(df_uniform.x, df_normal_a.z)

# %%
plt.scatter(df_uniform.x, df_normal_b.z)

# %%
plt.scatter(df_uniform.x, df_uniform.y)
