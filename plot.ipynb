# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_normal = pd.read_csv('output/normal_points.csv')
df_uniform = pd.read_csv('output/uniform_points.csv')

# %%
plt.scatter(df_normal.x, df_normal.y)

# %%
plt.scatter(df_uniform.x, df_uniform.y)
